# %%
import hopsworks
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import seaborn as sns
from matplotlib import pyplot
from hsml.schema import Schema
from hsml.model_schema import ModelSchema
import joblib
import os

# %%
# You have to set the environment variable 'HOPSWORKS_API_KEY' for login to succeed
project = hopsworks.login()
fs = project.get_feature_store()
# Out:
# Connection closed.
# Connected. Call `.close()` to terminate connection gracefully.
# DeprecationWarning: ssl.PROTOCOL_TLS is deprecated
# Multiple projects found.
#
# 	 (1) SMDL_A01
# 	 (2) kompot
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/194711
# Connected. Call `.close()` to terminate connection gracefully.

# %%
# The feature view is the input set of features for your model. The features can come from different feature groups.    
# You can select features from different feature groups and join them together to create a feature view
buoy_swells_huntington_fg = fs.get_feature_group(name="buoy_swells_huntington", version=1)
query = buoy_swells_huntington_fg.select_all()
df = query.read()
df['hits_at'] = df['hits_at'].dt.strftime('%Y-%m-%d %H')
buoy_swells_sorted = df.sort_values(by='hits_at', ascending=False)
buoy_swells_sorted
# Out:
# Finished: Reading data from Hopsworks, using ArrowFlight (1.76s)
#                    pred_dtime height period direction        hits_at  beach_id
# 597 2024-01-04 06:00:00+00:00   0.28   12.6        91  2024-01-14 19         1
# 591 2024-01-04 06:00:00+00:00   0.16   14.3        16  2024-01-14 19         1
# 589 2024-01-04 06:00:00+00:00   0.29   12.7        91  2024-01-14 18         1
# 585 2024-01-04 06:00:00+00:00   0.26   12.8        93  2024-01-14 17         1
# 588 2024-01-04 06:00:00+00:00   0.25   12.7        93  2024-01-14 17         1
# ..                        ...    ...    ...       ...            ...       ...
# 25  2023-12-29 00:00:00+00:00   1.45   17.3        89  2023-12-29 03         1
# 86  2023-12-29 00:00:00+00:00   1.46   17.4        89  2023-12-29 02         1
# 284 2023-12-29 00:00:00+00:00   1.46   17.6        89  2023-12-29 01         1
# 365 2023-12-29 00:00:00+00:00   1.45   17.7        89  2023-12-29 01         1
# 141 2023-12-29 00:00:00+00:00   1.43   17.9        89  2023-12-29 00         1
#
# [805 rows x 6 columns]

# %%
beach_swells_huntington_fg = fs.get_feature_group(name="beach_swells_huntington", version=1)
query2 = beach_swells_huntington_fg.select_all()
df2 = query2.read()
df2['datetime'] = df2['datetime'].dt.strftime('%Y-%m-%d %H')
beach_swells_sorted = df2.sort_values(by='datetime', ascending=False)
beach_swells_sorted
# Out:
# Finished: Reading data from Hopsworks, using ArrowFlight (1.22s)
#          quality       datetime  year  month  day  hour  minute
# 33          Fair  2024-01-04 12  2024      1    4    12      30
# 32          Fair  2024-01-04 08  2024      1    4     8       0
# 31  Fair To Good  2024-01-04 07  2024      1    4     7       0
# 30  Fair To Good  2024-01-04 06  2024      1    4     6       0
# 10   0.17   13.3        12  2024-01-04 06         1  Fair To Good  2024
# 11   1.64    5.6        94  2024-01-03 12         1          Poor  2024
# 12   0.35    4.0        82  2024-01-03 08         1          Poor  2024
# 13   0.56   11.3        80  2024-01-02 12         1          Fair  2024
# 14   0.19   12.7        13  2024-01-02 08         1  Poor To Fair  2024
# 15   0.20   13.5        14  2024-01-01 12         1          Fair  2024
# 16   0.21   14.1        13  2024-01-01 08         1          Fair  2024
# 17   0.20   14.1        11  2023-12-31 12         1          Fair  2023
# 18   0.20   14.6        10  2023-12-31 08         1          Fair  2023
# 19   0.19   15.5        11  2023-12-30 12         1          Poor  2023
# 20   0.18   16.0        13  2023-12-30 08         1  Poor To Fair  2023
# 21   1.01   15.6        88  2023-12-29 12         1  Poor To Fair  2023
# 22   1.18   16.1        89  2023-12-29 08         1          Poor  2023
#
#     month  day  hour  minute
# 0       1    4    12      30
# 1       1    4    12      30
# 2       1    4    12      30
# 3       1    4     8       0
# 4       1    4     8       0
# 5       1    4     8       0
# 6       1    4     7       0
# 7       1    4     7       0
# 8       1    4     7       0
# 9       1    4     6       0
# 10      1    4     6       0
# 11      1    3    12      30
# 12      1    3     8       0
# 13      1    2    12      30
# 14      1    2     8       0
# 15      1    1    12      30
# 16      1    1     8       0
# 17     12   31    12      30
# 18     12   31     8       0
# 19     12   30    12      30
# 20     12   30     8       0
# 21     12   29    12      30
# 22     12   29     8       0

# %%
# Save the merged DataFrame as a new Feature Group
merged_fg = fs.get_or_create_feature_group(name="merged_swells_huntington",
                version=2,
                primary_key=['year','month','day','hour','minute'],
                description="Merged swell from buoy and huntington website",
                online_enabled=True,
                statistics_config={"enabled": True, "histograms": True, "correlations": True},
                )
merged_fg.insert(merged_df)
# Out:
# Feature Group created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/194711/fs/194630/fg/386410
# Uploading Dataframe: 0.00% |          | Rows 0/23 | Elapsed Time: 00:00 | Remaining Time: ?
# Launching job: merged_swells_huntington_2_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://c.app.hopsworks.ai/p/194711/jobs/named/merged_swells_huntington_2_offline_fg_materialization/executions
# (<hsfs.core.job.Job at 0x28b267af0>, None)

# %%
# The feature view is the input set of features for your model. The features can come from different feature groups.    
# You can select features from different feature groups and join them together to create a feature view
merged_fg = fs.get_feature_group(name="merged_swells_huntington", version=2)
query = merged_fg.select(['height','period','direction','quality'])
feature_view = fs.get_or_create_feature_view(name="merged_swells_huntington",
                                  version=3,
                                  description="Feature view combining the buoy swells and the beach swells",
                                  labels=["quality"],
                                  query=query)
# Out:
# Feature view created successfully, explore it at
# https://c.app.hopsworks.ai:443/p/194711/fs/194630/fv/merged_swells_huntington/version/3
